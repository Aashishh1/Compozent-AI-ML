# %% [markdown]
# <h2> <b>Write a program to perform addition, subtraction,
# multiplication, and division of two numbers provided by
# the user </b> <h2>

# %%
# Addition
num1 = float(input("Enter the first number for addition: "))
num2 = float(input("Enter the second number for addition: "))
sum_result = num1 + num2
print(f"sum: {num1} + {num2} = {sum_result}")
# Out:
# sum: 2.0 + 5.0 = 7.0

# %%
# Substraction
num3 = float(input("Enter the first number for subtraction: "))
num4 = float(input("Enter the second number for subtraction: "))
difference = num3 - num4
print(f"Difference: {num3} - {num4} = {difference}")
# Out:
# Difference: 10.0 - 3.0 = 7.0

# %%
# Multiplication:
num5 = float(input("Enter the first number for multiplication: "))
num6 = float(input("Enter the second number for multiplication: "))
product = num5 * num6
print(f"Product: {num5} * {num6} = {product}")
# Out:
# Product: 7.0 * 1.0 = 7.0

# %%
# Division
num7 = float(input("Enter the dividend for division: "))
num8 = float(input("Enter the divisor for division: "))
if num8 == 0:
 print("Error: Division by zero is not allowed.")
else:
 div_result = num7 / num8
 print(f"Division: {num7} / {num8} = {div_result}")
# Out:
# Division: 49.0 / 7.0 = 7.0
